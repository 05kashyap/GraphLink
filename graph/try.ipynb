# %%
import networkx as nx
Social = nx.DiGraph()

# %%
social_g = {}
k = [1,2,3,4,5,6,7,8,9,0]
m = ['a','w','b','c','d']
for a in m:
    social_g[a] = k

for u, v in social_g.items():
    for b in v:
        Social.add_edge(u,b)

nx.draw_shell(Social, with_labels= True)
